# %% [markdown]
# # FIN-XR Exploratory Data Analysis (EDA)
# ## 1. Bank Transaction Pattern Intelligence (`bank.xlsx`)
# ## 2. Supervised Fraud Intelligence (`creditcard.csv`)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_dir = '../data'
print('Data directory contents:', os.listdir(data_dir) if os.path.exists(data_dir) else 'Directory missing')
